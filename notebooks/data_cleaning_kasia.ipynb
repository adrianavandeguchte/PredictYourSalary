# %%
import pandas as pd

# %%
# import csv to df
salary_df1 = pd.read_csv("../imported_data/salary_data2.csv", header=3)
salary_df1.head()
# Out:
#    423  40-44    Male  -1      India  Professional degree Software Engineer  \
# 0   83  55-59  Female  -1    Germany  Professional degree               NaN
# 1  391  40-44    Male  -1  Australia      Master’s degree             Other
# 2  392  22-24    Male  -1      India    Bachelor’s degree             Other
# 3  470  50-54    Male  -1     France      Master’s degree    Data Scientist
# 4  529  22-24    Male  -1      India      Master’s degree    Data Scientist
#
#    -1.1  > 10,000 employees    20+  ... Unnamed: 236 Unnamed: 237  \
# 0    -1                 NaN    NaN  ...          NaN          NaN
# 1     0  > 10,000 employees    20+  ...          NaN          NaN
# 2     1      0-49 employees      0  ...          NaN          NaN
# 3    -1      0-49 employees  4-Mar  ...          NaN          NaN
# 4    -1    50-249 employees    20+  ...          NaN          NaN
#
#   Unnamed: 238                     Unnamed: 239 Unnamed: 240  \
# ...
