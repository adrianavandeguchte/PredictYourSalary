# %%
import pandas as pd

# %%
# import csv to df
salary_df1 = pd.read_csv("../imported_data/salary_data1.csv", header=3)
salary_df1.head()
# Out:
#    Survey Year         Timestamp SalaryUSD         Country PostalCode  \
# 0         2017  1/5/2017 5:10:20    200000   United States  Not Asked
# 1         2017  1/5/2017 5:26:23     61515  United Kingdom  Not Asked
# 2         2017  1/5/2017 5:32:57     95000         Germany  Not Asked
# 3         2017  1/5/2017 5:33:03     56000  United Kingdom  Not Asked
# 4         2017  1/5/2017 5:34:34     35000          France  Not Asked
#
#         PrimaryDatabase  YearsWithThisDatabase  \
# 0  Microsoft SQL Server                     10
# 1  Microsoft SQL Server                     15
# 2  Microsoft SQL Server                      5
# 3  Microsoft SQL Server                      6
# 4  Microsoft SQL Server                     10
#
#                     OtherDatabases  \
# 0                    MySQL/MariaDB
# 1               Oracle, PostgreSQL
# 2  Oracle, MySQL/MariaDB, Informix
# 3                              NaN
# 4                           Oracle
#
#                                     EmploymentStatus JobTitle  ...  \
# 0                                 Full time employee      DBA  ...
# 1                                 Full time employee      DBA  ...
# 2                                 Full time employee    Other  ...
# 3                                 Full time employee      DBA  ...
# 4  Full time employee of a consulting/contracting...      DBA  ...
#
#   HoursWorkedPerWeek             TelecommuteDaysPerWeek  \
# 0                 45                                  1
# 1                 35                                  2
# 2                 45  None, or less than 1 day per week
# 3                 40                                  1
# 4                 40  None, or less than 1 day per week
#
#   PopulationOfLargestCityWithin20Miles  EmploymentSector  \
# 0                            Not Asked  Private business
# 1                            Not Asked  Private business
# 2                            Not Asked  Private business
# 3                            Not Asked  Private business
# 4                            Not Asked  Private business
#
#                      LookingForAnotherJob  CareerPlansThisYear     Gender  \
# 0  Yes, but only passively (just curious)            Not Asked  Not Asked
# 1                                      No            Not Asked  Not Asked
# 2  Yes, but only passively (just curious)            Not Asked  Not Asked
# 3  Yes, but only passively (just curious)            Not Asked  Not Asked
# 4  Yes, but only passively (just curious)            Not Asked  Not Asked
#
#   OtherJobDuties KindsOfTasksPerformed  Counter
# 0      Not Asked             Not Asked        1
# 1      Not Asked             Not Asked        1
# 2      Not Asked             Not Asked        1
# 3      Not Asked             Not Asked        1
# 4      Not Asked             Not Asked        1
#
# [5 rows x 29 columns]

# %%
# take only the columns we need
salary_df1 = salary_df1[["Survey Year", "SalaryUSD", "Country", "PrimaryDatabase", "YearsWithThisDatabase", "EmploymentStatus", "JobTitle", "ManageStaff", "YearsWithThisTypeOfJob", "OtherPeopleOnYourTeam", "DatabaseServers", "Education", "EducationIsComputerRelated", "Certifications", "HoursWorkedPerWeek", "TelecommuteDaysPerWeek", "EmploymentSector"]]
salary_df1
# Out:
#       Survey Year SalaryUSD         Country       PrimaryDatabase  \
# 0            2017    200000   United States  Microsoft SQL Server
# 1            2017     61515  United Kingdom  Microsoft SQL Server
# 2            2017     95000         Germany  Microsoft SQL Server
# 3            2017     56000  United Kingdom  Microsoft SQL Server
# 4            2017     35000          France  Microsoft SQL Server
# ...           ...       ...             ...                   ...
# 6888         2019     32000         Hungary  Microsoft SQL Server
# 6889         2019     32000         Hungary  Microsoft SQL Server
# 6890         2019     40000        Portugal  Microsoft SQL Server
# 6891         2019    130000   United States  Microsoft SQL Server
# 6892         2019     84500          Canada  Microsoft SQL Server
#
#       YearsWithThisDatabase  \
# 0                        10
# 1                        15
# 2                         5
# 3                         6
# 4                        10
# ...                     ...
# 6888                      3
# 6889                      3
# 6890                     10
# 6891                     20
# 6892                     19
#
#                                        EmploymentStatus  \
# 0                                    Full time employee
# 1                                    Full time employee
# 2                                    Full time employee
# 3                                    Full time employee
# 4     Full time employee of a consulting/contracting...
# ...                                                 ...
# 6888                                 Full time employee
# 6889                                 Full time employee
# 6890  Full time employee of a consulting/contracting...
# 6891  Full time employee of a consulting/contracting...
# 6892                                 Full time employee
#
#                                                JobTitle ManageStaff  \
# 0                                                   DBA          No
# 1                                                   DBA          No
# 2                                                 Other         Yes
# 3                                                   DBA          No
# 4                                                   DBA          No
# ...                                                 ...         ...
# 6888  DBA (General - splits time evenly between writ...          No
# 6889  DBA (General - splits time evenly between writ...          No
# 6890                  Developer: App code (C#, JS, etc)         Yes
# 6891  DBA (General - splits time evenly between writ...          No
# 6892                                          Architect          No
#
#       YearsWithThisTypeOfJob OtherPeopleOnYourTeam  DatabaseServers  \
# 0                          5                     2              350
# 1                          3                     1               40
# 2                         25                     2              100
# 3                          2                  None              500
# 4                         10                  None               30
# ...                      ...                   ...              ...
# 6888                       3           More than 5             1000
# 6889                       3           More than 5             1000
# 6890                      19                     1                5
# 6891                      17                     5              100
# 6892                      19                  None               20
#
#                        Education EducationIsComputerRelated  \
# 0                        Masters                         No
# 1     None (no degree completed)                        NaN
# 2                        Masters                        Yes
# 3           Associates (2 years)                         No
# 4            Bachelors (4 years)                        Yes
# ...                          ...                        ...
# 6888         Bachelors (4 years)                        Yes
# 6889         Bachelors (4 years)                        Yes
# 6890         Bachelors (4 years)                        Yes
# 6891         Bachelors (4 years)                        Yes
# 6892         Bachelors (4 years)                        Yes
#
#                         Certifications  HoursWorkedPerWeek  \
# 0     Yes, and they're currently valid                  45
# 1                     No, I never have                  35
# 2                Yes, but they expired                  45
# 3                     No, I never have                  40
# 4                Yes, but they expired                  40
# ...                                ...                 ...
# 6888  Yes, and they're currently valid                  40
# 6889  Yes, and they're currently valid                  40
# 6890  Yes, and they're currently valid                  40
# 6891             Yes, but they expired                  42
# 6892                  No, I never have                  40
#
#                  TelecommuteDaysPerWeek  EmploymentSector
# 0                                     1  Private business
# 1                                     2  Private business
# 2     None, or less than 1 day per week  Private business
# 3                                     1  Private business
# 4     None, or less than 1 day per week  Private business
# ...                                 ...               ...
# 6888                                  2  Private business
# 6889                                  2  Private business
# 6890  None, or less than 1 day per week  Private business
# 6891  None, or less than 1 day per week  Private business
# 6892  None, or less than 1 day per week  Private business
#
# [6893 rows x 17 columns]

# %%
# check the datatypes to see what needs to be changed
salary_df1.dtypes
# Out:
# Survey Year                    int64
# SalaryUSD                     object
# Country                       object
# PrimaryDatabase               object
# YearsWithThisDatabase          int64
# EmploymentStatus              object
# JobTitle                      object
# ManageStaff                   object
# YearsWithThisTypeOfJob         int64
# OtherPeopleOnYourTeam         object
# DatabaseServers                int64
# Education                     object
# EducationIsComputerRelated    object
# Certifications                object
# HoursWorkedPerWeek             int64
# TelecommuteDaysPerWeek        object
# EmploymentSector              object
# dtype: object

# %%
# take out non-integer characters in the salary column
salary_df1["SalaryUSD"] = salary_df1["SalaryUSD"].str.replace(",", "")
salary_df1["SalaryUSD"] = salary_df1["SalaryUSD"].str.replace(" ", "")
salary_df1["SalaryUSD"] = salary_df1["SalaryUSD"].str.replace("$", "")
# change the salary type to float
salary_df1["SalaryUSD"] = salary_df1["SalaryUSD"].astype(float)
# check to make sure the salary column is correct data type
salary_df1.dtypes
# Out:
# Survey Year                     int64
# SalaryUSD                     float64
# Country                        object
# PrimaryDatabase                object
# YearsWithThisDatabase           int64
# EmploymentStatus               object
# JobTitle                       object
# ManageStaff                    object
# YearsWithThisTypeOfJob          int64
# OtherPeopleOnYourTeam          object
# DatabaseServers                 int64
# Education                      object
# EducationIsComputerRelated     object
# Certifications                 object
# HoursWorkedPerWeek              int64
# TelecommuteDaysPerWeek         object
# EmploymentSector               object
# dtype: object

# %%
# only take salaries that are greater than 1000 to get rid of low outliers
salary_df1 = salary_df1.loc[salary_df1["SalaryUSD"] > 1000]
salary_df1
# Out:
#       Survey Year  SalaryUSD         Country       PrimaryDatabase  \
# 0            2017   200000.0   United States  Microsoft SQL Server
# 1            2017    61515.0  United Kingdom  Microsoft SQL Server
# 2            2017    95000.0         Germany  Microsoft SQL Server
# 3            2017    56000.0  United Kingdom  Microsoft SQL Server
# 4            2017    35000.0          France  Microsoft SQL Server
# ...           ...        ...             ...                   ...
# 6888         2019    32000.0         Hungary  Microsoft SQL Server
# 6889         2019    32000.0         Hungary  Microsoft SQL Server
# 6890         2019    40000.0        Portugal  Microsoft SQL Server
# 6891         2019   130000.0   United States  Microsoft SQL Server
# 6892         2019    84500.0          Canada  Microsoft SQL Server
#
#       YearsWithThisDatabase  \
# 0                        10
# 1                        15
# 2                         5
# 3                         6
# 4                        10
# ...                     ...
# 6888                      3
# 6889                      3
# 6890                     10
# 6891                     20
# 6892                     19
#
#                                        EmploymentStatus  \
# 0                                    Full time employee
# 1                                    Full time employee
# 2                                    Full time employee
# 3                                    Full time employee
# 4     Full time employee of a consulting/contracting...
# ...                                                 ...
# 6888                                 Full time employee
# 6889                                 Full time employee
# 6890  Full time employee of a consulting/contracting...
# 6891  Full time employee of a consulting/contracting...
# 6892                                 Full time employee
#
#                                                JobTitle ManageStaff  \
# 0                                                   DBA          No
# 1                                                   DBA          No
# 2                                                 Other         Yes
# 3                                                   DBA          No
# 4                                                   DBA          No
# ...                                                 ...         ...
# 6888  DBA (General - splits time evenly between writ...          No
# 6889  DBA (General - splits time evenly between writ...          No
# 6890                  Developer: App code (C#, JS, etc)         Yes
# 6891  DBA (General - splits time evenly between writ...          No
# 6892                                          Architect          No
#
#       YearsWithThisTypeOfJob OtherPeopleOnYourTeam  DatabaseServers  \
# 0                          5                     2              350
# 1                          3                     1               40
# 2                         25                     2              100
# 3                          2                  None              500
# 4                         10                  None               30
# ...                      ...                   ...              ...
# 6888                       3           More than 5             1000
# 6889                       3           More than 5             1000
# 6890                      19                     1                5
# 6891                      17                     5              100
# 6892                      19                  None               20
#
#                        Education EducationIsComputerRelated  \
# 0                        Masters                         No
# 1     None (no degree completed)                        NaN
# 2                        Masters                        Yes
# 3           Associates (2 years)                         No
# 4            Bachelors (4 years)                        Yes
# ...                          ...                        ...
# 6888         Bachelors (4 years)                        Yes
# 6889         Bachelors (4 years)                        Yes
# 6890         Bachelors (4 years)                        Yes
# 6891         Bachelors (4 years)                        Yes
# 6892         Bachelors (4 years)                        Yes
#
#                         Certifications  HoursWorkedPerWeek  \
# 0     Yes, and they're currently valid                  45
# 1                     No, I never have                  35
# 2                Yes, but they expired                  45
# 3                     No, I never have                  40
# 4                Yes, but they expired                  40
# ...                                ...                 ...
# 6888  Yes, and they're currently valid                  40
# 6889  Yes, and they're currently valid                  40
# 6890  Yes, and they're currently valid                  40
# 6891             Yes, but they expired                  42
# 6892                  No, I never have                  40
#
#                  TelecommuteDaysPerWeek  EmploymentSector
# 0                                     1  Private business
# 1                                     2  Private business
# 2     None, or less than 1 day per week  Private business
# 3                                     1  Private business
# 4     None, or less than 1 day per week  Private business
# ...                                 ...               ...
# 6888                                  2  Private business
# 6889                                  2  Private business
# 6890  None, or less than 1 day per week  Private business
# 6891  None, or less than 1 day per week  Private business
# 6892  None, or less than 1 day per week  Private business
#
# [6874 rows x 17 columns]

# %%
# take out incorrect/nonsensical data from "YearsWithThisDatabase"
salary_df1 = salary_df1.loc[(salary_df1["YearsWithThisDatabase"] < 2050)]
salary_df1 = salary_df1.loc[(salary_df1["YearsWithThisDatabase"] != 1050)]
salary_df1
# Out:
#       Survey Year  SalaryUSD         Country       PrimaryDatabase  \
# 0            2017   200000.0   United States  Microsoft SQL Server
# 1            2017    61515.0  United Kingdom  Microsoft SQL Server
# 2            2017    95000.0         Germany  Microsoft SQL Server
# 3            2017    56000.0  United Kingdom  Microsoft SQL Server
# 4            2017    35000.0          France  Microsoft SQL Server
# ...           ...        ...             ...                   ...
# 6888         2019    32000.0         Hungary  Microsoft SQL Server
# 6889         2019    32000.0         Hungary  Microsoft SQL Server
# 6890         2019    40000.0        Portugal  Microsoft SQL Server
# 6891         2019   130000.0   United States  Microsoft SQL Server
# 6892         2019    84500.0          Canada  Microsoft SQL Server
#
#       YearsWithThisDatabase  \
# 0                        10
# 1                        15
# 2                         5
# 3                         6
# 4                        10
# ...                     ...
# 6888                      3
# 6889                      3
# 6890                     10
# 6891                     20
# 6892                     19
#
#                                        EmploymentStatus  \
# 0                                    Full time employee
# 1                                    Full time employee
# 2                                    Full time employee
# 3                                    Full time employee
# 4     Full time employee of a consulting/contracting...
# ...                                                 ...
# 6888                                 Full time employee
# 6889                                 Full time employee
# 6890  Full time employee of a consulting/contracting...
# 6891  Full time employee of a consulting/contracting...
# 6892                                 Full time employee
#
#                                                JobTitle ManageStaff  \
# 0                                                   DBA          No
# 1                                                   DBA          No
# 2                                                 Other         Yes
# 3                                                   DBA          No
# 4                                                   DBA          No
# ...                                                 ...         ...
# 6888  DBA (General - splits time evenly between writ...          No
# 6889  DBA (General - splits time evenly between writ...          No
# 6890                  Developer: App code (C#, JS, etc)         Yes
# 6891  DBA (General - splits time evenly between writ...          No
# 6892                                          Architect          No
#
#       YearsWithThisTypeOfJob OtherPeopleOnYourTeam  DatabaseServers  \
# 0                          5                     2              350
# 1                          3                     1               40
# 2                         25                     2              100
# 3                          2                  None              500
# 4                         10                  None               30
# ...                      ...                   ...              ...
# 6888                       3           More than 5             1000
# 6889                       3           More than 5             1000
# 6890                      19                     1                5
# 6891                      17                     5              100
# 6892                      19                  None               20
#
#                        Education EducationIsComputerRelated  \
# 0                        Masters                         No
# 1     None (no degree completed)                        NaN
# 2                        Masters                        Yes
# 3           Associates (2 years)                         No
# 4            Bachelors (4 years)                        Yes
# ...                          ...                        ...
# 6888         Bachelors (4 years)                        Yes
# 6889         Bachelors (4 years)                        Yes
# 6890         Bachelors (4 years)                        Yes
# 6891         Bachelors (4 years)                        Yes
# 6892         Bachelors (4 years)                        Yes
#
#                         Certifications  HoursWorkedPerWeek  \
# 0     Yes, and they're currently valid                  45
# 1                     No, I never have                  35
# 2                Yes, but they expired                  45
# 3                     No, I never have                  40
# 4                Yes, but they expired                  40
# ...                                ...                 ...
# 6888  Yes, and they're currently valid                  40
# 6889  Yes, and they're currently valid                  40
# 6890  Yes, and they're currently valid                  40
# 6891             Yes, but they expired                  42
# 6892                  No, I never have                  40
#
#                  TelecommuteDaysPerWeek  EmploymentSector
# 0                                     1  Private business
# 1                                     2  Private business
# 2     None, or less than 1 day per week  Private business
# 3                                     1  Private business
# 4     None, or less than 1 day per week  Private business
# ...                                 ...               ...
# 6888                                  2  Private business
# 6889                                  2  Private business
# 6890  None, or less than 1 day per week  Private business
# 6891  None, or less than 1 day per week  Private business
# 6892  None, or less than 1 day per week  Private business
#
# [6871 rows x 17 columns]

# %%
# some people entered the year they started instead of amount of years worked in the column "YearsWithThisDatabase"
# this loop takes the year they started and subtracts it from the year they took the survey to get the total yeras worked there
for index, row in salary_df1.iterrows():
    if row[4] > 1000:
        number = row[0] - row[4]
        # print out the number to make sure it worked
        print(number)
        salary_df1.at[index, "YearsWithThisDatabase"] = number

# sort in descending order to make sure numbers in the 2000s don't appear in the "YearsWithThisDatabase" column
salary_df1.sort_values("YearsWithThisDatabase", ascending = False)
# Out:
# 14
# 10
# 15
# 8
# 19
#       Survey Year  SalaryUSD         Country       PrimaryDatabase  \
# 1694         2017    51000.0   United States  Microsoft SQL Server
# 4843         2018   129000.0   United States  Microsoft SQL Server
# 688          2017   134000.0   United States  Microsoft SQL Server
# 6823         2019   500000.0     Switzerland  Microsoft SQL Server
# 650          2017    76650.0     Netherlands                   DB2
# ...           ...        ...             ...                   ...
# 2972         2018    48000.0   United States  Microsoft SQL Server
# 1216         2017    37166.0  United Kingdom  Microsoft SQL Server
# 3962         2018     6516.5    South Africa  Microsoft SQL Server
# 2479         2017    88000.0   United States            PostgreSQL
# 5154         2018    64000.0   United States  Microsoft SQL Server
#
#       YearsWithThisDatabase  \
# 1694                     38
# 4843                     32
# 688                      32
# 6823                     32
# 650                      31
# ...                     ...
# 2972                      0
# 1216                      0
# 3962                      0
# 2479                      0
# 5154                      0
#
#                                        EmploymentStatus  \
# 1694                                 Full time employee
# 4843                                 Full time employee
# 688                                  Full time employee
# 6823  Independent consultant, contractor, freelancer...
# 650          Independent or freelancer or company owner
# ...                                                 ...
# 2972                                 Full time employee
# 1216                                 Full time employee
# 3962                                 Full time employee
# 2479                                 Full time employee
# 5154                                 Full time employee
#
#                                                JobTitle ManageStaff  \
# 1694                                                DBA          No
# 4843                  Developer: App code (C#, JS, etc)         Yes
# 688                                           Architect         Yes
# 6823  DBA (General - splits time evenly between writ...         Yes
# 650                                                 DBA         Yes
# ...                                                 ...         ...
# 2972  DBA (Production Focus - build & troubleshoot s...          No
# 1216                                                DBA          No
# 3962  DBA (Development Focus - tunes queries, indexe...          No
# 2479                                            Analyst          No
# 5154                                              Other         Yes
#
#       YearsWithThisTypeOfJob OtherPeopleOnYourTeam  DatabaseServers  \
# 1694                       4                     3               20
# 4843                       9                     4               20
# 688                        2                  None               20
# 6823                      32           More than 5             1000
# 650                       37                  None               15
# ...                      ...                   ...              ...
# 2972                       0                  None              100
# 1216                       0                     1               50
# 3962                       0                     3                4
# 2479                       0           More than 5               10
# 5154                      14                  None                2
#
#                        Education EducationIsComputerRelated  \
# 1694         Bachelors (4 years)                        Yes
# 4843         Bachelors (4 years)                         No
# 688         Associates (2 years)                        Yes
# 6823                     Masters                        Yes
# 650          Bachelors (4 years)                        Yes
# ...                          ...                        ...
# 2972         Bachelors (4 years)                         No
# 1216        Associates (2 years)                        Yes
# 3962  None (no degree completed)                        NaN
# 2479         Bachelors (4 years)                         No
# 5154         Bachelors (4 years)                        Yes
#
#                         Certifications  HoursWorkedPerWeek  \
# 1694  Yes, and they're currently valid                  40
# 4843                  No, I never have                  50
# 688                   No, I never have                  65
# 6823  Yes, and they're currently valid                  70
# 650              Yes, but they expired                  36
# ...                                ...                 ...
# 2972                  No, I never have                  40
# 1216                  No, I never have                  37
# 3962  Yes, and they're currently valid                  40
# 2479                  No, I never have                  45
# 5154                  No, I never have                  45
#
#                  TelecommuteDaysPerWeek  EmploymentSector
# 1694  None, or less than 1 day per week  Private business
# 4843                                  1  Private business
# 688   None, or less than 1 day per week  Private business
# 6823                                  3  Private business
# 650                                   4  Private business
# ...                                 ...               ...
# 2972  None, or less than 1 day per week  Private business
# 1216  None, or less than 1 day per week  Private business
# 3962  None, or less than 1 day per week  Private business
# 2479  None, or less than 1 day per week  Private business
# 5154  None, or less than 1 day per week  Private business
#
# [6871 rows x 17 columns]

# %%
# we only needed the "survey year" column to complete the previous step, so we are removing it now
del salary_df1["Survey Year"]
salary_df1
# Out:
#       SalaryUSD         Country       PrimaryDatabase  YearsWithThisDatabase  \
# 0      200000.0   United States  Microsoft SQL Server                     10
# 1       61515.0  United Kingdom  Microsoft SQL Server                     15
# 2       95000.0         Germany  Microsoft SQL Server                      5
# 3       56000.0  United Kingdom  Microsoft SQL Server                      6
# 4       35000.0          France  Microsoft SQL Server                     10
# ...         ...             ...                   ...                    ...
# 6888    32000.0         Hungary  Microsoft SQL Server                      3
# 6889    32000.0         Hungary  Microsoft SQL Server                      3
# 6890    40000.0        Portugal  Microsoft SQL Server                     10
# 6891   130000.0   United States  Microsoft SQL Server                     20
# 6892    84500.0          Canada  Microsoft SQL Server                     19
#
#                                        EmploymentStatus  \
# 0                                    Full time employee
# 1                                    Full time employee
# 2                                    Full time employee
# 3                                    Full time employee
# 4     Full time employee of a consulting/contracting...
# ...                                                 ...
# 6888                                 Full time employee
# 6889                                 Full time employee
# 6890  Full time employee of a consulting/contracting...
# 6891  Full time employee of a consulting/contracting...
# 6892                                 Full time employee
#
#                                                JobTitle ManageStaff  \
# 0                                                   DBA          No
# 1                                                   DBA          No
# 2                                                 Other         Yes
# 3                                                   DBA          No
# 4                                                   DBA          No
# ...                                                 ...         ...
# 6888  DBA (General - splits time evenly between writ...          No
# 6889  DBA (General - splits time evenly between writ...          No
# 6890                  Developer: App code (C#, JS, etc)         Yes
# 6891  DBA (General - splits time evenly between writ...          No
# 6892                                          Architect          No
#
#       YearsWithThisTypeOfJob OtherPeopleOnYourTeam  DatabaseServers  \
# 0                          5                     2              350
# 1                          3                     1               40
# 2                         25                     2              100
# 3                          2                  None              500
# 4                         10                  None               30
# ...                      ...                   ...              ...
# 6888                       3           More than 5             1000
# 6889                       3           More than 5             1000
# 6890                      19                     1                5
# 6891                      17                     5              100
# 6892                      19                  None               20
#
#                        Education EducationIsComputerRelated  \
# 0                        Masters                         No
# 1     None (no degree completed)                        NaN
# 2                        Masters                        Yes
# 3           Associates (2 years)                         No
# 4            Bachelors (4 years)                        Yes
# ...                          ...                        ...
# 6888         Bachelors (4 years)                        Yes
# 6889         Bachelors (4 years)                        Yes
# 6890         Bachelors (4 years)                        Yes
# 6891         Bachelors (4 years)                        Yes
# 6892         Bachelors (4 years)                        Yes
#
#                         Certifications  HoursWorkedPerWeek  \
# 0     Yes, and they're currently valid                  45
# 1                     No, I never have                  35
# 2                Yes, but they expired                  45
# 3                     No, I never have                  40
# 4                Yes, but they expired                  40
# ...                                ...                 ...
# 6888  Yes, and they're currently valid                  40
# 6889  Yes, and they're currently valid                  40
# 6890  Yes, and they're currently valid                  40
# 6891             Yes, but they expired                  42
# 6892                  No, I never have                  40
#
#                  TelecommuteDaysPerWeek  EmploymentSector
# 0                                     1  Private business
# 1                                     2  Private business
# 2     None, or less than 1 day per week  Private business
# 3                                     1  Private business
# 4     None, or less than 1 day per week  Private business
# ...                                 ...               ...
# 6888                                  2  Private business
# 6889                                  2  Private business
# 6890  None, or less than 1 day per week  Private business
# 6891  None, or less than 1 day per week  Private business
# 6892  None, or less than 1 day per week  Private business
#
# [6871 rows x 16 columns]

# %%
# remove rows where the job title only has 1-2 entries for that title
salary_df1.drop(salary_df1[(salary_df1['JobTitle'] == "Analytics consultant") ].index, inplace=True)
salary_df1.drop(salary_df1[(salary_df1['JobTitle'] == "Consultant") ].index, inplace=True)
salary_df1.drop(salary_df1[(salary_df1['JobTitle'] == "Database Specialist") ].index, inplace=True)
salary_df1.drop(salary_df1[(salary_df1['JobTitle'] == "Sales") ].index, inplace=True)
salary_df1.drop(salary_df1[(salary_df1['JobTitle'] == "Sr Consultant ") ].index, inplace=True)
salary_df1.drop(salary_df1[(salary_df1['JobTitle'] == "Systems Administrator") ].index, inplace=True)
salary_df1.drop(salary_df1[(salary_df1['JobTitle'] == "Technician ") ].index, inplace=True)
salary_df1.drop(salary_df1[(salary_df1['JobTitle'] == "Technician ") ].index, inplace=True)
salary_df1.drop(salary_df1[(salary_df1['JobTitle'] == "Data Scientist") ].index, inplace=True)
salary_df1.drop(salary_df1[(salary_df1['JobTitle'] == "Other") ].index, inplace=True)

salary_df1.drop(salary_df1[(salary_df1['EmploymentStatus'] == "Part time") ].index, inplace=True)

salary_df1.drop(salary_df1[(salary_df1['EmploymentSector'] == "Student") ].index, inplace=True)

salary_df1.drop(salary_df1[(salary_df1['HoursWorkedPerWeek'] > 90) ].index, inplace=True)

salary_df1
# Out:
#       SalaryUSD         Country       PrimaryDatabase  YearsWithThisDatabase  \
# 0      200000.0   United States  Microsoft SQL Server                     10
# 1       61515.0  United Kingdom  Microsoft SQL Server                     15
# 3       56000.0  United Kingdom  Microsoft SQL Server                      6
# 4       35000.0          France  Microsoft SQL Server                     10
# 5      215000.0  United Kingdom  Microsoft SQL Server                     15
# ...         ...             ...                   ...                    ...
# 6888    32000.0         Hungary  Microsoft SQL Server                      3
# 6889    32000.0         Hungary  Microsoft SQL Server                      3
# 6890    40000.0        Portugal  Microsoft SQL Server                     10
# 6891   130000.0   United States  Microsoft SQL Server                     20
# 6892    84500.0          Canada  Microsoft SQL Server                     19
#
#                                        EmploymentStatus   JobTitle  \
# 0                                    Full time employee        DBA
# 1                                    Full time employee        DBA
# 3                                    Full time employee        DBA
# 4     Full time employee of a consulting/contracting...        DBA
# 5            Independent or freelancer or company owner        DBA
# ...                                                 ...        ...
# 6888                                 Full time employee        DBA
# 6889                                 Full time employee        DBA
# 6890  Full time employee of a consulting/contracting...  Developer
# 6891  Full time employee of a consulting/contracting...        DBA
# 6892                                 Full time employee  Architect
#
#      ManageStaff  YearsWithThisTypeOfJob OtherPeopleOnYourTeam  \
# 0             No                       5                     2
# 1             No                       3                     1
# 3             No                       2                  None
# 4             No                      10                  None
# 5             No                      15                  None
# ...          ...                     ...                   ...
# 6888          No                       3           More than 5
# 6889          No                       3           More than 5
# 6890         Yes                      19                     1
# 6891          No                      17                     5
# 6892          No                      19                  None
#
#       DatabaseServers                   Education EducationIsComputerRelated  \
# 0                 350                     Masters                         No
# 1                  40  None (no degree completed)                        NaN
# 3                 500        Associates (2 years)                         No
# 4                  30         Bachelors (4 years)                        Yes
# 5                 101         Bachelors (4 years)                         No
# ...               ...                         ...                        ...
# 6888             1000         Bachelors (4 years)                        Yes
# 6889             1000         Bachelors (4 years)                        Yes
# 6890                5         Bachelors (4 years)                        Yes
# 6891              100         Bachelors (4 years)                        Yes
# 6892               20         Bachelors (4 years)                        Yes
#
#                         Certifications  HoursWorkedPerWeek  \
# 0     Yes, and they're currently valid                  45
# 1                     No, I never have                  35
# 3                     No, I never have                  40
# 4                Yes, but they expired                  40
# 5                Yes, but they expired                  35
# ...                                ...                 ...
# 6888  Yes, and they're currently valid                  40
# 6889  Yes, and they're currently valid                  40
# 6890  Yes, and they're currently valid                  40
# 6891             Yes, but they expired                  42
# 6892                  No, I never have                  40
#
#                  TelecommuteDaysPerWeek  EmploymentSector
# 0                                     1  Private business
# 1                                     2  Private business
# 3                                     1  Private business
# 4     None, or less than 1 day per week  Private business
# 5     None, or less than 1 day per week  Private business
# ...                                 ...               ...
# 6888                                  2  Private business
# 6889                                  2  Private business
# 6890  None, or less than 1 day per week  Private business
# 6891  None, or less than 1 day per week  Private business
# 6892  None, or less than 1 day per week  Private business
#
# [6693 rows x 16 columns]

# %%
# group job titles into more organized categories
salary_df1.loc[salary_df1["JobTitle"] == "DBA (Development Focus - tunes queries, indexes, does deployments)", "JobTitle"] = "DBA"
salary_df1.loc[salary_df1["JobTitle"] == "DBA (General - splits time evenly between writing & tuning queries AND building & troubleshooting servers)", "JobTitle"] = "DBA"
salary_df1.loc[salary_df1["JobTitle"] == "DBA (Production Focus - build & troubleshoot servers, HA/DR)", "JobTitle"] = "DBA"

salary_df1.loc[salary_df1["JobTitle"] == "DevOps, Sr Software Engineer DBA", "JobTitle"] = "Engineer"
salary_df1.loc[salary_df1["JobTitle"] == "Principal database engineer", "JobTitle"] = "Engineer"

salary_df1.loc[salary_df1["JobTitle"] == "DBA / BI Developer", "JobTitle"] = "Developer"
salary_df1.loc[salary_df1["JobTitle"] == "Developer: App code (C#, JS, etc)", "JobTitle"] = "Developer"
salary_df1.loc[salary_df1["JobTitle"] == "Developer: T-SQL", "JobTitle"] = "Developer"
salary_df1.loc[salary_df1["JobTitle"] == "Developer: Business Intelligence (SSRS, PowerBI, etc)", "JobTitle"] = "Developer"

salary_df1.loc[salary_df1["EmploymentStatus"] == "Full time employee of a consulting/contracting company", "EmploymentStatus"] = "Full time employee"
salary_df1.loc[salary_df1["EmploymentStatus"] == "Independent consultant, contractor, freelancer,  or company owner", "EmploymentStatus"] = "Independent Consultant/Freelancer"
salary_df1.loc[salary_df1["EmploymentStatus"] == "Independent or freelancer or company owner", "EmploymentStatus"] = "Independent Consultant/Freelancer"

salary_df1.loc[salary_df1["EmploymentSector"] == "Federal government", "EmploymentSector"] = "Government"
salary_df1.loc[salary_df1["EmploymentSector"] == "Local government", "EmploymentSector"] = "Government"
salary_df1.loc[salary_df1["EmploymentSector"] == "State/province government", "EmploymentSector"] = "Government"

salary_df1["EmploymentStatus"].value_counts()
# Out:
# Full time employee                   6432
# Independent Consultant/Freelancer     261
# Name: EmploymentStatus, dtype: int64

# %%
# import the country to regions csv
country_to_region_df = pd.read_csv("../imported_data/country_to_region.csv")
country_to_region_df
# Out:
#       Country          Region
# 0      Canada   North America
# 1      Russia  Eastern Europe
# 2   Indonesia            Asia
# 3   Argentina   Latin America
# 4    Colombia   Latin America
# ..        ...             ...
# 80     Taiwan            Asia
# 81   Thailand            Asia
# 82    Uruguay   South America
# 83  Venezuela   South America
# 84    Vietnam            Asia
#
# [85 rows x 2 columns]

# %%
# merge salary df with county to region df so each row specifies the region as well as country
merged_df = pd.merge(salary_df1, country_to_region_df, on="Country", how="outer")
merged_df
# Out:
#       SalaryUSD        Country       PrimaryDatabase  YearsWithThisDatabase  \
# 0      200000.0  United States  Microsoft SQL Server                   10.0
# 1      137500.0  United States  Microsoft SQL Server                   16.0
# 2       85000.0  United States  Microsoft SQL Server                    8.0
# 3       96000.0  United States  Microsoft SQL Server                    5.0
# 4       66000.0  United States  Microsoft SQL Server                   10.0
# ...         ...            ...                   ...                    ...
# 6691    35100.0      Guatemala  Microsoft SQL Server                    1.0
# 6692    51000.0         Taiwan  Microsoft SQL Server                   13.0
# 6693        NaN      Indonesia                   NaN                    NaN
# 6694        NaN        Albania                   NaN                    NaN
# 6695        NaN      Venezuela                   NaN                    NaN
#
#         EmploymentStatus   JobTitle ManageStaff  YearsWithThisTypeOfJob  \
# 0     Full time employee        DBA          No                     5.0
# 1     Full time employee        DBA          No                     6.0
# 2     Full time employee        DBA          No                     2.0
# 3     Full time employee        DBA          No                     5.0
# 4     Full time employee  Developer          No                    10.0
# ...                  ...        ...         ...                     ...
# 6691  Full time employee        DBA          No                     1.0
# 6692  Full time employee        DBA          No                    10.0
# 6693                 NaN        NaN         NaN                     NaN
# 6694                 NaN        NaN         NaN                     NaN
# 6695                 NaN        NaN         NaN                     NaN
#
#      OtherPeopleOnYourTeam  DatabaseServers                   Education  \
# 0                        2            350.0                     Masters
# 1                        4            200.0  None (no degree completed)
# 2                     None             15.0         Bachelors (4 years)
# 3                     None            100.0                     Masters
# 4                     None              4.0        Associates (2 years)
# ...                    ...              ...                         ...
# 6691                     2            170.0         Bachelors (4 years)
# 6692           More than 5            100.0                     Masters
# 6693                   NaN              NaN                         NaN
# 6694                   NaN              NaN                         NaN
# 6695                   NaN              NaN                         NaN
#
#      EducationIsComputerRelated                    Certifications  \
# 0                            No  Yes, and they're currently valid
# 1                           NaN  Yes, and they're currently valid
# 2                           Yes                  No, I never have
# 3                            No                  No, I never have
# 4                           NaN                  No, I never have
# ...                         ...                               ...
# 6691                        Yes  Yes, and they're currently valid
# 6692                        Yes             Yes, but they expired
# 6693                        NaN                               NaN
# 6694                        NaN                               NaN
# 6695                        NaN                               NaN
#
#       HoursWorkedPerWeek             TelecommuteDaysPerWeek  EmploymentSector  \
# 0                   45.0                                  1  Private business
# 1                   55.0                          5 or more  Private business
# 2                   50.0  None, or less than 1 day per week  Private business
# 3                   45.0                                  1  Private business
# 4                   60.0                          5 or more  Private business
# ...                  ...                                ...               ...
# 6691                44.0  None, or less than 1 day per week  Private business
# 6692                40.0  None, or less than 1 day per week  Private business
# 6693                 NaN                                NaN               NaN
# 6694                 NaN                                NaN               NaN
# 6695                 NaN                                NaN               NaN
#
#               Region
# 0      North America
# 1      North America
# 2      North America
# 3      North America
# 4      North America
# ...              ...
# 6691   South America
# 6692            Asia
# 6693            Asia
# 6694  Eastern Europe
# 6695   South America
#
# [6696 rows x 17 columns]

# %%
# delete 3 rows where the row is just NaN's
index_of_random_nan = merged_df[((merged_df.index == 6693))]
merged_df.drop(index_of_random_nan.index, inplace=True)
merged_df = merged_df[:-2]
merged_df
# Out:
#       SalaryUSD             Country       PrimaryDatabase  \
# 0      200000.0       United States  Microsoft SQL Server
# 1      137500.0       United States  Microsoft SQL Server
# 2       85000.0       United States  Microsoft SQL Server
# 3       96000.0       United States  Microsoft SQL Server
# 4       66000.0       United States  Microsoft SQL Server
# ...         ...                 ...                   ...
# 6688     7500.0               Ghana  Microsoft SQL Server
# 6689    22350.0  Dominican Republic  Microsoft SQL Server
# 6690    17333.0             Uruguay  Microsoft SQL Server
# 6691    35100.0           Guatemala  Microsoft SQL Server
# 6692    51000.0              Taiwan  Microsoft SQL Server
#
#       YearsWithThisDatabase    EmploymentStatus   JobTitle ManageStaff  \
# 0                      10.0  Full time employee        DBA          No
# 1                      16.0  Full time employee        DBA          No
# 2                       8.0  Full time employee        DBA          No
# 3                       5.0  Full time employee        DBA          No
# 4                      10.0  Full time employee  Developer          No
# ...                     ...                 ...        ...         ...
# 6688                    4.0  Full time employee  Developer         Yes
# 6689                   11.0  Full time employee        DBA          No
# 6690                    7.0  Full time employee        DBA         Yes
# 6691                    1.0  Full time employee        DBA          No
# 6692                   13.0  Full time employee        DBA          No
#
#       YearsWithThisTypeOfJob OtherPeopleOnYourTeam  DatabaseServers  \
# 0                        5.0                     2            350.0
# 1                        6.0                     4            200.0
# 2                        2.0                  None             15.0
# 3                        5.0                  None            100.0
# 4                       10.0                  None              4.0
# ...                      ...                   ...              ...
# 6688                     8.0                     2              2.0
# 6689                     1.0                     3             46.0
# 6690                     7.0                     2             20.0
# 6691                     1.0                     2            170.0
# 6692                    10.0           More than 5            100.0
#
#                        Education EducationIsComputerRelated  \
# 0                        Masters                         No
# 1     None (no degree completed)                        NaN
# 2            Bachelors (4 years)                        Yes
# 3                        Masters                         No
# 4           Associates (2 years)                        NaN
# ...                          ...                        ...
# 6688        Associates (2 years)                        Yes
# 6689  None (no degree completed)                        NaN
# 6690         Bachelors (4 years)                        Yes
# 6691         Bachelors (4 years)                        Yes
# 6692                     Masters                        Yes
#
#                         Certifications  HoursWorkedPerWeek  \
# 0     Yes, and they're currently valid                45.0
# 1     Yes, and they're currently valid                55.0
# 2                     No, I never have                50.0
# 3                     No, I never have                45.0
# 4                     No, I never have                60.0
# ...                                ...                 ...
# 6688             Yes, but they expired                40.0
# 6689                  No, I never have                44.0
# 6690                  No, I never have                35.0
# 6691  Yes, and they're currently valid                44.0
# 6692             Yes, but they expired                40.0
#
#                  TelecommuteDaysPerWeek  EmploymentSector         Region
# 0                                     1  Private business  North America
# 1                             5 or more  Private business  North America
# 2     None, or less than 1 day per week  Private business  North America
# 3                                     1  Private business  North America
# 4                             5 or more  Private business  North America
# ...                                 ...               ...            ...
# 6688  None, or less than 1 day per week  Private business         Africa
# 6689  None, or less than 1 day per week  Private business  North America
# 6690                          5 or more  Private business  South America
# 6691  None, or less than 1 day per week  Private business  South America
# 6692  None, or less than 1 day per week  Private business           Asia
#
# [6693 rows x 17 columns]

# %%
# rename all column headers to be lowercase to fit postgres format
merged_df.columns = map(str.lower, merged_df.columns)
merged_df
# Out:
#       salaryusd             country       primarydatabase  \
# 0      200000.0       United States  Microsoft SQL Server
# 1      137500.0       United States  Microsoft SQL Server
# 2       85000.0       United States  Microsoft SQL Server
# 3       96000.0       United States  Microsoft SQL Server
# 4       66000.0       United States  Microsoft SQL Server
# ...         ...                 ...                   ...
# 6689    22350.0  Dominican Republic  Microsoft SQL Server
# 6690    17333.0             Uruguay  Microsoft SQL Server
# 6691    35100.0           Guatemala  Microsoft SQL Server
# 6692    51000.0              Taiwan  Microsoft SQL Server
# 6693        NaN           Indonesia                   NaN
#
#       yearswiththisdatabase    employmentstatus   jobtitle managestaff  \
# 0                      10.0  Full time employee        DBA          No
# 1                      16.0  Full time employee        DBA          No
# 2                       8.0  Full time employee        DBA          No
# 3                       5.0  Full time employee        DBA          No
# 4                      10.0  Full time employee  Developer          No
# ...                     ...                 ...        ...         ...
# 6689                   11.0  Full time employee        DBA          No
# 6690                    7.0  Full time employee        DBA         Yes
# 6691                    1.0  Full time employee        DBA          No
# 6692                   13.0  Full time employee        DBA          No
# 6693                    NaN                 NaN        NaN         NaN
#
#       yearswiththistypeofjob otherpeopleonyourteam  databaseservers  \
# 0                        5.0                     2            350.0
# 1                        6.0                     4            200.0
# 2                        2.0                  None             15.0
# 3                        5.0                  None            100.0
# 4                       10.0                  None              4.0
# ...                      ...                   ...              ...
# 6689                     1.0                     3             46.0
# 6690                     7.0                     2             20.0
# 6691                     1.0                     2            170.0
# 6692                    10.0           More than 5            100.0
# 6693                     NaN                   NaN              NaN
#
#                        education educationiscomputerrelated  \
# 0                        Masters                         No
# 1     None (no degree completed)                        NaN
# 2            Bachelors (4 years)                        Yes
# 3                        Masters                         No
# 4           Associates (2 years)                        NaN
# ...                          ...                        ...
# 6689  None (no degree completed)                        NaN
# 6690         Bachelors (4 years)                        Yes
# 6691         Bachelors (4 years)                        Yes
# 6692                     Masters                        Yes
# 6693                         NaN                        NaN
#
#                         certifications  hoursworkedperweek  \
# 0     Yes, and they're currently valid                45.0
# 1     Yes, and they're currently valid                55.0
# 2                     No, I never have                50.0
# 3                     No, I never have                45.0
# 4                     No, I never have                60.0
# ...                                ...                 ...
# 6689                  No, I never have                44.0
# 6690                  No, I never have                35.0
# 6691  Yes, and they're currently valid                44.0
# 6692             Yes, but they expired                40.0
# 6693                               NaN                 NaN
#
#                  telecommutedaysperweek  employmentsector         region
# 0                                     1  Private business  North America
# 1                             5 or more  Private business  North America
# 2     None, or less than 1 day per week  Private business  North America
# 3                                     1  Private business  North America
# 4                             5 or more  Private business  North America
# ...                                 ...               ...            ...
# 6689  None, or less than 1 day per week  Private business  North America
# 6690                          5 or more  Private business  South America
# 6691  None, or less than 1 day per week  Private business  South America
# 6692  None, or less than 1 day per week  Private business           Asia
# 6693                                NaN               NaN           Asia
#
# [6694 rows x 17 columns]

# %%
# makes a column called id to be used as the primary key
merged_df = merged_df.reset_index()
merged_df = merged_df.rename(columns={"index":"id"})
merged_df
# Out:
#         id  salaryusd             country       primarydatabase  \
# 0        0   200000.0       United States  Microsoft SQL Server
# 1        1   137500.0       United States  Microsoft SQL Server
# 2        2    85000.0       United States  Microsoft SQL Server
# 3        3    96000.0       United States  Microsoft SQL Server
# 4        4    66000.0       United States  Microsoft SQL Server
# ...    ...        ...                 ...                   ...
# 6689  6689    22350.0  Dominican Republic  Microsoft SQL Server
# 6690  6690    17333.0             Uruguay  Microsoft SQL Server
# 6691  6691    35100.0           Guatemala  Microsoft SQL Server
# 6692  6692    51000.0              Taiwan  Microsoft SQL Server
# 6693  6693        NaN           Indonesia                   NaN
#
#       yearswiththisdatabase    employmentstatus   jobtitle managestaff  \
# 0                      10.0  Full time employee        DBA          No
# 1                      16.0  Full time employee        DBA          No
# 2                       8.0  Full time employee        DBA          No
# 3                       5.0  Full time employee        DBA          No
# 4                      10.0  Full time employee  Developer          No
# ...                     ...                 ...        ...         ...
# 6689                   11.0  Full time employee        DBA          No
# 6690                    7.0  Full time employee        DBA         Yes
# 6691                    1.0  Full time employee        DBA          No
# 6692                   13.0  Full time employee        DBA          No
# 6693                    NaN                 NaN        NaN         NaN
#
#       yearswiththistypeofjob otherpeopleonyourteam  databaseservers  \
# 0                        5.0                     2            350.0
# 1                        6.0                     4            200.0
# 2                        2.0                  None             15.0
# 3                        5.0                  None            100.0
# 4                       10.0                  None              4.0
# ...                      ...                   ...              ...
# 6689                     1.0                     3             46.0
# 6690                     7.0                     2             20.0
# 6691                     1.0                     2            170.0
# 6692                    10.0           More than 5            100.0
# 6693                     NaN                   NaN              NaN
#
#                        education educationiscomputerrelated  \
# 0                        Masters                         No
# 1     None (no degree completed)                        NaN
# 2            Bachelors (4 years)                        Yes
# 3                        Masters                         No
# 4           Associates (2 years)                        NaN
# ...                          ...                        ...
# 6689  None (no degree completed)                        NaN
# 6690         Bachelors (4 years)                        Yes
# 6691         Bachelors (4 years)                        Yes
# 6692                     Masters                        Yes
# 6693                         NaN                        NaN
#
#                         certifications  hoursworkedperweek  \
# 0     Yes, and they're currently valid                45.0
# 1     Yes, and they're currently valid                55.0
# 2                     No, I never have                50.0
# 3                     No, I never have                45.0
# 4                     No, I never have                60.0
# ...                                ...                 ...
# 6689                  No, I never have                44.0
# 6690                  No, I never have                35.0
# 6691  Yes, and they're currently valid                44.0
# 6692             Yes, but they expired                40.0
# 6693                               NaN                 NaN
#
#                  telecommutedaysperweek  employmentsector         region
# 0                                     1  Private business  North America
# 1                             5 or more  Private business  North America
# 2     None, or less than 1 day per week  Private business  North America
# 3                                     1  Private business  North America
# 4                             5 or more  Private business  North America
# ...                                 ...               ...            ...
# 6689  None, or less than 1 day per week  Private business  North America
# 6690                          5 or more  Private business  South America
# 6691  None, or less than 1 day per week  Private business  South America
# 6692  None, or less than 1 day per week  Private business           Asia
# 6693                                NaN               NaN           Asia
#
# [6694 rows x 18 columns]

# %%
# get list of columns to make postgresql schema
merged_df.keys()
# Out:
# Index(['id', 'salaryusd', 'country', 'primarydatabase',
#        'yearswiththisdatabase', 'employmentstatus', 'jobtitle', 'managestaff',
#        'yearswiththistypeofjob', 'otherpeopleonyourteam', 'databaseservers',
#        'education', 'educationiscomputerrelated', 'certifications',
#        'hoursworkedperweek', 'telecommutedaysperweek', 'employmentsector',
#        'region'],
#       dtype='object')

# %%
# get data types of columns to make postgresql schema
merged_df.dtypes
# Out:
# id                              int64
# salaryusd                     float64
# country                        object
# primarydatabase                object
# yearswiththisdatabase         float64
# employmentstatus               object
# jobtitle                       object
# managestaff                    object
# yearswiththistypeofjob        float64
# otherpeopleonyourteam          object
# databaseservers               float64
# education                      object
# educationiscomputerrelated     object
# certifications                 object
# hoursworkedperweek            float64
# telecommutedaysperweek         object
# employmentsector               object
# region                         object
# dtype: object

# %%
# load the cleaned df to a csv
merged_df.to_csv("../exported_data/salary_data1.csv")

# %%
# Configure settings for RDS
from config import sandy_RDS_username
from config import sandy_RDS_password
from config import sandy_RDS_endpoint
from sqlalchemy import create_engine

rds_connection_string = f'{sandy_RDS_username}:{sandy_RDS_password}@{sandy_RDS_endpoint}:5432/predict_salary_db'
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# check that connection worked
engine.table_names()
# Out:
# ['salary_data1']

# %%
# adds dataframe to RDS
merged_df.to_sql(name='salary_data1', con=engine, if_exists='append', index=False)

# %%
# Check to confirm that data was loaded successfully
pd.read_sql_query('select * from salary_data1', con=engine)
# Out:
#         id  salaryusd             country       primarydatabase  \
# 0        0     200000       United States  Microsoft SQL Server
# 1        1     137500       United States  Microsoft SQL Server
# 2        2      85000       United States  Microsoft SQL Server
# 3        3      96000       United States  Microsoft SQL Server
# 4        4      66000       United States  Microsoft SQL Server
# ...    ...        ...                 ...                   ...
# 6723  6723       7500               Ghana  Microsoft SQL Server
# 6724  6724      22350  Dominican Republic  Microsoft SQL Server
# 6725  6725      17333             Uruguay  Microsoft SQL Server
# 6726  6726      35100           Guatemala  Microsoft SQL Server
# 6727  6727      51000              Taiwan  Microsoft SQL Server
#
#       yearswiththisdatabase  \
# 0                        10
# 1                        16
# 2                         8
# 3                         5
# 4                        10
# ...                     ...
# 6723                      4
# 6724                     11
# 6725                      7
# 6726                      1
# 6727                     13
#
#                                        employmentstatus   jobtitle  \
# 0                                    Full time employee        DBA
# 1     Full time employee of a consulting/contracting...        DBA
# 2                                    Full time employee        DBA
# 3                                    Full time employee        DBA
# 4                                    Full time employee  Developer
# ...                                                 ...        ...
# 6723                                 Full time employee  Developer
# 6724                                 Full time employee        DBA
# 6725                                 Full time employee        DBA
# 6726  Full time employee of a consulting/contracting...        DBA
# 6727                                 Full time employee        DBA
#
#      managestaff  yearswiththistypeofjob otherpeopleonyourteam  \
# 0             No                       5                     2
# 1             No                       6                     4
# 2             No                       2                  None
# 3             No                       5                  None
# 4             No                      10                  None
# ...          ...                     ...                   ...
# 6723         Yes                       8                     2
# 6724          No                       1                     3
# 6725         Yes                       7                     2
# 6726          No                       1                     2
# 6727          No                      10           More than 5
#
#       databaseservers                   education educationiscomputerrelated  \
# 0                 350                     Masters                         No
# 1                 200  None (no degree completed)                       None
# 2                  15         Bachelors (4 years)                        Yes
# 3                 100                     Masters                         No
# 4                   4        Associates (2 years)                       None
# ...               ...                         ...                        ...
# 6723                2        Associates (2 years)                        Yes
# 6724               46  None (no degree completed)                       None
# 6725               20         Bachelors (4 years)                        Yes
# 6726              170         Bachelors (4 years)                        Yes
# 6727              100                     Masters                        Yes
#
#                         certifications  hoursworkedperweek  \
# 0     Yes, and they're currently valid                  45
# 1     Yes, and they're currently valid                  55
# 2                     No, I never have                  50
# 3                     No, I never have                  45
# 4                     No, I never have                  60
# ...                                ...                 ...
# 6723             Yes, but they expired                  40
# 6724                  No, I never have                  44
# 6725                  No, I never have                  35
# 6726  Yes, and they're currently valid                  44
# 6727             Yes, but they expired                  40
#
#                  telecommutedaysperweek  employmentsector         region
# 0                                     1  Private business  North America
# 1                             5 or more  Private business  North America
# 2     None, or less than 1 day per week  Private business  North America
# 3                                     1  Private business  North America
# 4                             5 or more  Private business  North America
# ...                                 ...               ...            ...
# 6723  None, or less than 1 day per week  Private business         Africa
# 6724  None, or less than 1 day per week  Private business  North America
# 6725                          5 or more  Private business  South America
# 6726  None, or less than 1 day per week  Private business  South America
# 6727  None, or less than 1 day per week  Private business           Asia
#
# [6728 rows x 18 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize distribution of data
plt.figure(figsize=(15,10)) 
sns.distplot(merged_df["salaryusd"])
# plt.xlabel("Duration (minutes)", labelpad=14)
# plt.ylabel("Probability of occurence", labelpad=14)
# plt.title("Distribution of Duration", y=1.015, fontsize=20)

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(merged_df["salaryusd"]))
print(z)
# Out:
# [nan nan nan ... nan nan nan]

# %%
import scipy.stats as sts

z_scipy = sts.zscore(merged_df["salaryusd"].values)
z_scipy
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
merged_df["salaryusd"].values[
# Out:
#   File "<ipython-input-74-5fd84d2dc5ad>", line 1
#     merged_df["salaryusd"].values[
#                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
merged_df["salaryusd"].describe()
# Out:
# count    6.693000e+03
# mean     9.299401e+04
# std      5.541676e+04
# min      1.050000e+03
# 25%      6.500000e+04
# 50%      9.000000e+04
# 75%      1.150000e+05
# max      1.450000e+06
# Name: salaryusd, dtype: float64

# %%
print(merged_df[pd.to_numeric(merged_df["salaryusd"], errors='coerce').isnull()])
# Out:
#         id  salaryusd    country primarydatabase  yearswiththisdatabase  \
# 6693  6693        NaN  Indonesia             NaN                    NaN
#
#      employmentstatus jobtitle managestaff  yearswiththistypeofjob  \
# 6693              NaN      NaN         NaN                     NaN
#
#      otherpeopleonyourteam  databaseservers education  \
# 6693                   NaN              NaN       NaN
#
#      educationiscomputerrelated certifications  hoursworkedperweek  \
# 6693                        NaN            NaN                 NaN
#
#      telecommutedaysperweek employmentsector region
# 6693                    NaN              NaN   Asia
